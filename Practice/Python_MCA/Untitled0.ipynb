# %%
import numpy
arr=numpy.array([[10,12,32,66,55,44,10,11,12],[22,55,6,5,8,9,7,8,10]])
print(arr)

print(arr.ndim)
# Out:
# [[10 12 32 66 55 44 10 11 12]
#  [22 55  6  5  8  9  7  8 10]]
# 2

# %%
import numpy 
arr=numpy.array([15,17,18,20,22,99,100,98,17,50])
print(arr)

print(arr[3:8])
print(arr[3:8:2])
print(arr[0:])
print(arr[:10])

print("Negative Indices")
print(arr[-8:-3])
print(arr[-8:-3:2])
print(arr[-1:])
print(arr[:-10])
print(arr.ndim)
# Out:
# [ 15  17  18  20  22  99 100  98  17  50]
# [ 20  22  99 100  98]
# [20 99 98]
# [ 15  17  18  20  22  99 100  98  17  50]
# [ 15  17  18  20  22  99 100  98  17  50]
# Negative Indices
# [ 18  20  22  99 100]
# [ 18  22 100]
# [50]
# []
# 1

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])
x=arr.copy()
arr[0]=41

print(arr)
print(x)
# Out:
# [41  2  3  4  5  6]
# [1 2 3 4 5 6]

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])
x=arr.view()
arr[0]=41

print(arr)
print(x)
# Out:
# [41  2  3  4  5  6]
# [41  2  3  4  5  6]

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6])

for x in arr:
  print(x,end=" ")
# Out:
# 1 2 3 4 5 6

# %%
import numpy
arr=numpy.array([[10,12,32,66,55,44,10,11,12],[22,55,6,5,8,9,7,8,10]])

for x in arr:
  for y in x:
    print(y,end=" ")
  print("")
# Out:
# 10 12 32 66 55 44 10 11 12
# 22 55 6 5 8 9 7 8 10

# %%
import numpy
arr=numpy.array([10,12,32,66,55,44,10,11,12])
arr1=numpy.array([22,55,6,5,8,9,7,8,10,11,13])
arr2=numpy.concatenate((arr,arr1))
print(arr2)
# Out:
# [10 12 32 66 55 44 10 11 12 22 55  6  5  8  9  7  8 10 11 13]

# %%
import numpy
arr=numpy.array([10,12,32,66,55,44,10,11,12])
arr1=numpy.array([22,55,6,5,8,9,7,8,10])

arr2=numpy.stack((arr,arr1))
arr3=numpy.hstack((arr,arr1))
arr4=numpy.vstack((arr,arr1))
print(arr2)
print(arr3)
print(arr4)
# Out:
# [[10 12 32 66 55 44 10 11 12]
#  [22 55  6  5  8  9  7  8 10]]
# [10 12 32 66 55 44 10 11 12 22 55  6  5  8  9  7  8 10]
# [[10 12 32 66 55 44 10 11 12]
#  [22 55  6  5  8  9  7  8 10]]

# %%
import numpy
arr=numpy.array([[10,12,32,66,55,44,10,11,12],[22,55,6,5,8,9,7,8,10]])
arr1=numpy.array([22,55,6,5,8,9,7,8,10])
n=arr1.reshape(3,3)

print(arr.shape)
print(n)
# Out:
# (2, 9)
# [[22 55  6]
#  [ 5  8  9]
#  [ 7  8 10]]

# %% [markdown]
# #Pandas

# %%
import pandas as pd1
df= [{'x':1,'y':2,'z':3},{'x':5,'y':6}]
data = pd1.DataFrame(df)
print(data)
# Out:
#    x  y    z
# 0  1  2  3.0
# 1  5  6  NaN

# %%
import numpy as np
arr1=np.array([22,55,6,5,8,9,7,8,10])
x=np.array_split(arr1,2)
print(x)
# Out:
# [array([22, 55,  6,  5,  8]), array([ 9,  7,  8, 10])]

# %%
import numpy as np
arr1=np.array([22,55,6,5,8,9,7,8,10])
x=np.where(arr1==22)
print(x)
# Out:
# (array([0]),)

# %%
import numpy as np
arr1=np.array([22,55,6,5,8,9,7,8,10])
x=np.sort(arr1)
print(x)
# Out:
# [ 5  6  7  8  8  9 10 22 55]

# %%
import numpy as np
arr1=np.array([22,55,6,5,8,9,7,8,10])
x=[TRUE,FALSE,TRUE,TRUE,FALSE]
print(arr[x])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-7c20eafbd295> in <module>
#       1 import numpy as np
#       2 arr1=np.array([22,55,6,5,8,9,7,8,10])
# ----> 3 x=[TRUE,FALSE,TRUE,TRUE,FALSE]
#       4 print(arr[x])
#
# NameError: name 'TRUE' is not defined

# %%
import pandas as pd
import numpy as np
#Create a Dictionary of series
d = {'Name':pd.Series(['Tom','James','Ricky','Vin','Steve','Smith','Jack',
   'Lee','David','Gasper','Betina','Andres']),
   'Age':pd.Series([25,26,25,23,30,29,23,34,40,30,51,46]),
   'Rating':pd.Series([4.23,3.24,3.98,2.56,3.20,4.6,3.8,3.78,2.98,4.80,4.10,3.65])
}
#Create a DataFrame
df = pd.DataFrame(d)
print(df,df.sum(1),df.mean(1))
print(df,df.count(1),df.mode(1))
df.describe()
# Out:
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# 9   Gasper   30    4.80
# 10  Betina   51    4.10
# 11  Andres   46    3.65 0     29.23
# 1     29.24
# 2     28.98
# 3     25.56
# 4     33.20
# 5     33.60
# 6     26.80
# 7     37.78
# 8     42.98
# 9     34.80
# 10    55.10
# 11    49.65
# dtype: float64 0     14.615
# 1     14.620
# 2     14.490
# 3     12.780
# 4     16.600
# 5     16.800
# 6     13.400
# 7     18.890
# 8     21.490
# 9     17.400
# 10    27.550
# 11    24.825
# dtype: float64
#       Name  Age  Rating
# 0      Tom   25    4.23
# 1    James   26    3.24
# 2    Ricky   25    3.98
# 3      Vin   23    2.56
# 4    Steve   30    3.20
# 5    Smith   29    4.60
# 6     Jack   23    3.80
# 7      Lee   34    3.78
# 8    David   40    2.98
# ...

# %% [markdown]
# #Practice

# %%
import numpy as np
arr1=np.array([22,55,6,5,8,9,7,8,10])
print(np.where(arr1==55))
x=np.sort(arr1)
print(np.where(arr1==55))
print(x)
# Out:
# (array([1]),)
# (array([1]),)
# [ 5  6  7  8  8  9 10 22 55]

# %% [markdown]
# #Practice CLS

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([0,6])
ypoints = np.array([0,250])

plt.plot(xpoints,ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,1,8,10,12])
ypoints = np.array([5,9,3,1,10])

plt.plot(xpoints,ypoints, 'o')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,1,8,10,12])
ypoints = np.array([5,9,3,1,10])

plt.plot(xpoints,ypoints,'o:r',ms=10,mec='g',mfc='k')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,1,8,10,12])
ypoints = np.array([5,9,3,1,10])

plt.title("Random Data")
plt.xlabel("Increement X")
plt.ylabel("Increement Y")
plt.plot(xpoints,ypoints,'o:r',ms=10,mec='g',mfc='k')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,1,8,10,12])
ypoints = np.array([5,9,3,1,10])


arr1=np.array([22,55,6,5,8,9,7,8,10])
arr2=np.array([12,35,16,45,18,89,71,28,10])
plt.plot(arr1,arr2,'o:r',ms=10,mec='g',mfc='k')
plt.subplot(1,2,1)

plt.title("Random Data")
plt.xlabel("Increement X")
plt.ylabel("Increement Y")


plt.plot(xpoints,ypoints,'o:r',ms=10,mec='g',mfc='k')
plt.subplot(1,2,2)
plt.grid()
plt.show()

# %%
import numpy as np
arr1=np.array([22,55,6,5,8,9,7,8,10])
x=np.array_split(arr1,3)
print(x)
# Out:
# [array([22, 55,  6]), array([5, 8, 9]), array([ 7,  8, 10])]

# %%
import numpy as np
import pandas as pd
arr1=np.array([22,55,6,5,8,9,7,8,10])
x=np.where(arr1==22)
print(x)

y=pd.readcsv("")
# Out:
# (array([0]),)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-11-2d11ff774e41> in <module>
#       5 print(x)
#       6
# ----> 7 y=pd.readcsv()
#
# /usr/local/lib/python3.7/dist-packages/pandas/__init__.py in __getattr__(name)
#     242         return _SparseArray
#     243
# --> 244     raise AttributeError(f"module 'pandas' has no attribute '{name}'")
#     245
#     246
#
# AttributeError: module 'pandas' has no attribute 'readcsv'

# %% [markdown]
# # CA

# %%
import numpy as np
import pandas as pd

arr=np.array([1,2,3,4,5])
print("Positive Index")
print(arr[3])
print("Negative Index")
print(arr[-2])

print("")
print("Slicing with Positive Index")
print(arr[0:3])
print("Slicing with negative indexing")
print(arr[-4:-1])

x=np.vstack(arr)
y=np.hstack(arr)
z=np.stack(arr)
print("")
print("Vstack")
print(x)

print("")
print("Hstack")
print(y)

print("")
print("Stack")
print(z)
# Out:
# Positive Index
# 4
# Negative Index
# 4
#
# Slicing with Positive Index
# [1 2 3]
# Slicing wiht negative indexing
# [2 3 4]
#
# Vstack
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]
#
# Hstack
# [1 2 3 4 5]
#
# Stack
# [1 2 3 4 5]

# %%
# Out:
#   SUBDIVISION    YEAR   JAN   FEB   MAR    APR    MAY    JUN     JUL    AUG  \
# 0         NaN     NaN   NaN   NaN   NaN    NaN    NaN    NaN     NaN    NaN
# 1      KERALA  1901.0  28.7  44.7  51.6  160.0  174.7  824.6   743.0  357.5
# 2         NaN     NaN   NaN   NaN   NaN    NaN    NaN    NaN     NaN    NaN
# 3      KERALA  1902.0   6.7   2.6  57.3   83.9  134.5  390.9  1205.0  315.8
# 4         NaN     NaN   NaN   NaN   NaN    NaN    NaN    NaN     NaN    NaN
#
#      SEP    OCT    NOV    DEC  ANNUAL RAINFALL FLOODS
# 0    NaN    NaN    NaN    NaN              NaN    NaN
# 1  197.7  266.9  350.8   48.4           3248.6    YES
# 2    NaN    NaN    NaN    NaN              NaN    NaN
# 3  491.6  358.4  158.3  121.5           3326.6    YES
# 4    NaN    NaN    NaN    NaN              NaN    NaN

# %% [markdown]
# #Prediction Model

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import model_selection
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

df= pd.read_excel('kerala.xlsx')
df.head(5)
df.describe()
df.info()

X= df[['SEP', 'JUN', 'JUL']]  
Y= df[['FLOODS']]  
X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.4,random_state=100)

X_train,X_test,y_train,y_test=train_test_split(X,Y,test_size=0.4,random_state=100)
y_pred=logreg.predict(X_test)
print (X_test) #test dataset
print (y_pred) #predicted values
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 236 entries, 0 to 235
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   SUBDIVISION      118 non-null    object
#  1   YEAR             118 non-null    float64
#  2   JAN              118 non-null    float64
#  3   FEB              118 non-null    float64
#  4   MAR              118 non-null    float64
#  5   APR              118 non-null    float64
#  6   MAY              118 non-null    float64
#  7   JUN              118 non-null    float64
#  8   JUL              118 non-null    float64
#  9   AUG              118 non-null    float64
#  10  SEP              118 non-null    float64
#  11  OCT              118 non-null    float64
#  12  NOV              118 non-null    float64
#  13  DEC              118 non-null    float64
#  14  ANNUAL RAINFALL  118 non-null    float64
#  15  FLOODS           118 non-null    object
# ...
