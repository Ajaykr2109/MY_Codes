# %%
import pandas as pd
import numpy as np
#path='auto.csv'
df=pd.read_csv("D:\\LPU\\auto.csv")
#df.replace("?",np.nan,inplace=True)
df.corr()
# Out:
# C:\Users\ENGEE\AppData\Local\Temp\ipykernel_18996\1957536564.py:6: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#               3      88.6     168.8      64.1      48.8      2548       130  \
# 3      1.000000 -0.525095 -0.356792 -0.227799 -0.533078 -0.229281 -0.107229
# 88.6  -0.525095  1.000000  0.877612  0.795115  0.582603  0.781763  0.573989
# 168.8 -0.356792  0.877612  1.000000  0.841199  0.491969  0.878090  0.683830
# 64.1  -0.227799  0.795115  0.841199  1.000000  0.274075  0.868493  0.737042
# 48.8  -0.533078  0.582603  0.491969  0.274075  1.000000  0.298429  0.068577
# 2548  -0.229281  0.781763  0.878090  0.868493  0.298429  1.000000  0.850611
# 130   -0.107229  0.573989  0.683830  0.737042  0.068577  0.850611  1.000000
# 9.0   -0.177413  0.249199  0.157913  0.180287  0.261036  0.151372  0.029083
# 21    -0.030557 -0.479633 -0.673251 -0.647177 -0.055659 -0.758238 -0.654101
# 27     0.039598 -0.552897 -0.706635 -0.681169 -0.113995 -0.798088 -0.677775
#
#             9.0        21        27
# 3     -0.177413 -0.030557  0.039598
# 88.6   0.249199 -0.479633 -0.552897
# 168.8  0.157913 -0.673251 -0.706635
# 64.1   0.180287 -0.647177 -0.681169
# 48.8   0.261036 -0.055659 -0.113995
# 2548   0.151372 -0.758238 -0.798088
# 130    0.029083 -0.654101 -0.677775
# 9.0    1.000000  0.324186  0.264677
# 21     0.324186  1.000000  0.971311
# 27     0.264677  0.971311  1.000000

# %%
from sklearn import preprocessing 
from sklearn.linear_model import LinearRegression

lm=LinearRegression()
lm
# Out:
# LinearRegression()
